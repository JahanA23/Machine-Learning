# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# Load data
df = pd.read_csv('road_condition.csv')

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(df['Weather_Conditions'], df['Road_Surface'], test_size=0.2)

# Vectorize text data
vectorizer = TfidfVectorizer()
X_train_vectors = vectorizer.fit_transform(X_train)
X_test_vectors = vectorizer.transform(X_test)

# Train Naive Bayes classifier
clf = MultinomialNB()
clf.fit(X_train_vectors, y_train)

# Make predictions
y_pred = clf.predict(X_test_vectors)

# Evaluate accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7
#               precision    recall  f1-score   support
#
#          Dry       0.60      1.00      0.75        18
#  Frost / Ice       0.00      0.00      0.00         5
#   Wet / Damp       1.00      0.59      0.74        17
#
#     accuracy                           0.70        40
#    macro avg       0.53      0.53      0.50        40
# weighted avg       0.69      0.70      0.65        40
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
